# %%
import numpy as np, pandas as pd

data = pd.read_csv("intern.csv")
data.head()
# Out:
#    Campaign ID                     Campaign Name                  Audience  \
# 0  Campaign 11                SHU_Students (USA)                  Students
# 1   Campaign 7               SHU_Students(Nepal)                  Students
# 2   Campaign 9                 SHU_Students(UAE)                  Students
# 3   Campaign 5               SHU_Students(Ghana)                  Students
# 4   Campaign 1  SHU_6 (Educators and Principals)  Educators and Principals
#
#      Age                                          Geography  Reach  \
# 0  25-34                                                USA     91
# 1  13-17                                              Nepal   6145
# 2  13-17                                                UAE   1579
# 3  13-17                                              Ghana   5355
# 4  25-34  Group 1 (Australia, Canada, United Kingdom, Gh...  11387
#
#    Impressions  Frequency  Clicks  Unique Clicks  Unique Link Clicks (ULC)  \
# ...

# %%
data.info()
data.shape  # to check rows and columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Campaign ID                             33 non-null     object
#  1   Campaign Name                           33 non-null     object
#  2   Audience                                33 non-null     object
#  3   Age                                     33 non-null     object
#  4   Geography                               33 non-null     object
#  5   Reach                                   33 non-null     int64
#  6   Impressions                             33 non-null     int64
#  7   Frequency                               33 non-null     float64
#  8   Clicks                                  33 non-null     int64
#  9   Unique Clicks                           33 non-null     int64
# ...

# %%
#cleaning : are their any mssing value if so,drop such rows or replace them with estimated value
#count the null values
data.isnull().sum()
#observation no missing data
# how to use drop
#data1=data[~data.Rating.isnull()]
# Out:
# Campaign ID                               0
# Campaign Name                             0
# Audience                                  0
# Age                                       0
# Geography                                 0
# Reach                                     0
# Impressions                               0
# Frequency                                 0
# Clicks                                    0
# Unique Clicks                             0
# Unique Link Clicks (ULC)                  0
# Click-Through Rate (CTR)                  0
# Unique Click-Through Rate (Unique CTR)    0
# Amount Spent in INR                       0
# Cost per Result (CPR)                     0
# Cost Per Click (CPC)                      0
# Revenue                                   0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.hist(data.Reach,bins = 10)
# Out:
# (array([20.,  4.,  3.,  2.,  1.,  0.,  1.,  0.,  0.,  2.]),
#  array([   91. ,  3092.9,  6094.8,  9096.7, 12098.6, 15100.5, 18102.4,
#         21104.3, 24106.2, 27108.1, 30110. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.show()

# %%
plt.boxplot(data.Reach)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x229434ccc70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x229434db3a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x229434cc8b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x229434dbac0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x229434dbe50>],
#  'means': []}

# %%
#checking out the records with more than 30000 reach
data[data.Reach>=30000]
# Out:
#    Campaign ID         Campaign Name  Audience    Age Geography  Reach  \
# 15  Campaign 6  SHU_Students (India)  Students  18-24     India  30110
#
#     Impressions  Frequency  Clicks  Unique Clicks  Unique Link Clicks (ULC)  \
# 15        35372   1.174759    1308           1162                       934
#
#     Click-Through Rate (CTR)  Unique Click-Through Rate (Unique CTR)  \
# 15                   3.69784                                3.859183
#
#     Amount Spent in INR  Cost per Result (CPR)  Cost Per Click (CPC)  \
# 15                894.0                   0.96              0.683483
#
#        Revenue
# 15  893.995136

# %%
data[data.Reach > data.Impressions]
# Out:
# Empty DataFrame
# Columns: [Campaign ID, Campaign Name, Audience, Age, Geography, Reach, Impressions, Frequency, Clicks, Unique Clicks, Unique Link Clicks (ULC), Click-Through Rate (CTR), Unique Click-Through Rate (Unique CTR), Amount Spent in INR, Cost per Result (CPR), Cost Per Click (CPC), Revenue]
# Index: []

# %%
#how to drop certain rows
#data = data[data.Reach <30000]
plt.style.use("ggplot")

# %%
data["Campaign Name"].value_counts().plot.barh()
plt.show()

# %%
#what kind of relation ship between two numeric variables

#relationship between reach and impressions
import seaborn as sns


chart=sns.jointplot(data.Reach,data["Campaign ID","data.fr"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\VARSHI~1\AppData\Local\Temp/ipykernel_16408/3032396629.py in <module>
#       5
#       6
# ----> 7 chart=sns.jointplot(data.Reach,data["Campaign ID","data.fr"])
#
# NameError: name 'data' is not defined

# %%
sns.pairplot(data[["Reach","Clicks","Revenue"]],kind="kde")
plt.show()

# %%
sns.scatterplot(data=data, x="Reach", y="Impressions", hue="Campaign ID")
# Out:
# <AxesSubplot:xlabel='Reach', ylabel='Impressions'>

# %%
plt.style.use('dark_background')
sns.scatterplot(data=data, x="Reach", y="Impressions", hue="Campaign ID")
# Out:
# <AxesSubplot:xlabel='Reach', ylabel='Impressions'>

# %%
sns.scatterplot(data=data, x="Clicks", y="Reach", hue="Campaign ID")
# Out:
# <AxesSubplot:xlabel='Clicks', ylabel='Reach'>

# %%
sns.scatterplot(data=data, x="Reach", y="Revenue", hue="Campaign ID")
# Out:
# <AxesSubplot:xlabel='Reach', ylabel='Revenue'>

# %%
sns.pairplot(data, hue="Campaign ID", markers=["o", "s", "D"])
plt.show()

# %%
sns.pairplot(
    data,
    x_vars=["Reach","Frequency","Revenue"],
    y_vars=["Impressions", "Reach"],hue="Campaign ID"
)

# %%
data.groupby(["Campaign ID"]).mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='Campaign ID'>

# %%
sns.barplot(data=data, y = "Campaign ID", x="Reach",estimator =np.mean)
# Out:
# <AxesSubplot:xlabel='Reach', ylabel='Campaign ID'>

# %%
sns.barplot(data=data, y = "Campaign ID", x="Impressions",estimator =np.mean)
# Out:
# <AxesSubplot:xlabel='Impressions', ylabel='Campaign ID'>

# %%
sns.barplot(data=data, y = "Campaign ID", x="Clicks",estimator =np.mean)
# Out:
# <AxesSubplot:xlabel='Clicks', ylabel='Campaign ID'>

# %%
sns.barplot(data=data, x = "Reach", y="Revenue",estimator =np.mean)
# Out:
# <AxesSubplot:xlabel='Reach', ylabel='Revenue'>

# %%
sns.barplot(data=data, y = "Campaign ID", x="Revenue",estimator = lambda x: np.quantile(x,1))
# Out:
# <AxesSubplot:xlabel='Revenue', ylabel='Campaign ID'>

# %%
sns.boxplot(data["Revenue"])
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Revenue'>

# %%
sns.heatmap(res, cmap="Greens",annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\VARSHI~1\AppData\Local\Temp/ipykernel_24976/3555994428.py in <module>
# ----> 1 sns.heatmap(res, cmap="Greens",annot=True)
#
# NameError: name 'res' is not defined
